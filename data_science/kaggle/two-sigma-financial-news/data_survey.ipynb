# %% [markdown]
# # Two sigma financial news
#
# https://www.kaggle.com/c/two-sigma-financial-news/data

# %%
import pandas as pd
mktdata_df = pd.read_csv('/Users/hao.yan/data/two-sigma-financial-news/marketdata_sample.csv')
mktdata_df.head()
# Out:
#                         time assetCode                 assetName  universe  \
# 0  2007-02-01 22:00:00+00:00       A.N  Agilent Technologies Inc       1.0
# 1  2007-02-01 22:00:00+00:00     AAI.N      AirTran Holdings Inc       0.0
# 2  2007-02-01 22:00:00+00:00     AAP.N    Advance Auto Parts Inc       1.0
# 3  2007-02-01 22:00:00+00:00    AAPL.O                 Apple Inc       1.0
# 4  2007-02-01 22:00:00+00:00     ABB.N                   ABB Ltd       1.0
#
#        volume  close   open  returnsClosePrevRaw1  returnsOpenPrevRaw1  \
# 0   2606900.0  32.19  32.17              0.005938             0.005312
# 1   2051600.0  11.12  11.08              0.004517            -0.007168
# 2   1164800.0  37.51  37.99             -0.011594             0.025648
# 3  23747329.0  84.74  86.23             -0.011548             0.016324
# 4   1208600.0  18.02  18.01              0.011791             0.025043
#
#    returnsClosePrevMktres1  returnsOpenPrevMktres1  returnsClosePrevRaw10  \
# ...

# %%
news_df  = pd.read_csv('/Users/hao.yan/data/two-sigma-financial-news/news_sample.csv')
news_df.head()
# Out:
#                         time            sourceTimestamp  \
# 0  2007-01-01 04:29:32+00:00  2007-01-01 04:29:32+00:00
# 1  2007-01-01 07:03:35+00:00  2007-01-01 07:03:34+00:00
# 2  2007-01-01 11:29:56+00:00  2007-01-01 11:29:56+00:00
# 3  2007-01-01 12:08:37+00:00  2007-01-01 12:08:37+00:00
# 4  2007-01-01 12:08:37+00:00  2007-01-01 12:08:37+00:00
#
#                 firstCreated          sourceId  \
# 0  2007-01-01 04:29:32+00:00  e58c6279551b85cf
# 1  2007-01-01 07:03:34+00:00  5a31c4327427f63f
# 2  2007-01-01 11:29:56+00:00  1cefd27a40fabdfe
# 3  2007-01-01 12:08:37+00:00  23768af19dc69992
# 4  2007-01-01 12:08:37+00:00  23768af19dc69992
#
#                                             headline  urgency  takeSequence  \
# 0  China's Daqing pumps 43.41 mln tonnes of oil i...        3             1
# 1          FEATURE-In kidnapping, finesse works best        3             1
# 2         PRESS DIGEST - Wall Street Journal - Jan 1        3             1
# ...

# %%
mktdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
# time                        100 non-null object
# assetCode                   100 non-null object
# assetName                   100 non-null object
# universe                    100 non-null float64
# volume                      100 non-null float64
# close                       100 non-null float64
# open                        100 non-null float64
# returnsClosePrevRaw1        100 non-null float64
# returnsOpenPrevRaw1         100 non-null float64
# returnsClosePrevMktres1     0 non-null float64
# returnsOpenPrevMktres1      0 non-null float64
# returnsClosePrevRaw10       100 non-null float64
# returnsOpenPrevRaw10        100 non-null float64
# returnsClosePrevMktres10    0 non-null float64
# returnsOpenPrevMktres10     0 non-null float64
# returnsOpenNextMktres10     100 non-null float64
# dtypes: float64(13), object(3)
# memory usage: 12.6+ KB

# %%
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 35 columns):
# time                    100 non-null object
# sourceTimestamp         100 non-null object
# firstCreated            100 non-null object
# sourceId                100 non-null object
# headline                100 non-null object
# urgency                 100 non-null int64
# takeSequence            100 non-null int64
# provider                100 non-null object
# subjects                100 non-null object
# audiences               100 non-null object
# bodySize                100 non-null int64
# companyCount            100 non-null int64
# headlineTag             36 non-null object
# marketCommentary        100 non-null bool
# sentenceCount           100 non-null int64
# wordCount               100 non-null int64
# assetCodes              100 non-null object
# assetName               100 non-null object
# firstMentionSentence    100 non-null int64
# ...

# %%
mktdata_df.assetCode.value_counts()
# Out:
# AJG.N     1
# ADM.N     1
# AMAT.O    1
# APA.N     1
# AEP.N     1
# AH.N      1
# AMTD.O    1
# AGE.N     1
# AKR.N     1
# ANDE.O    1
# AEA.N     1
# ABT.N     1
# AD.N      1
# APH.N     1
# AMP.N     1
# APPB.O    1
# ADCT.O    1
# APKT.O    1
# AMKR.O    1
# ABM.N     1
# ACS.N     1
# ALU.N     1
# AINV.O    1
# ABY.N     1
# AEL.N     1
# AIN.N     1
# APOL.O    1
# AHL.N     1
# AOS.N     1
# AMX.N     1
#          ..
# ACXM.O    1
# ABD.N     1
# APC.N     1
# A.N       1
# AIT.N     1
# AHG.N     1
# AMLN.O    1
# ADI.N     1
# AMD.N     1
# ALB.N     1
# AG.N      1
# ADTN.O    1
# ALD.N     1
# ACH.N     1
# AFFX.O    1
# ACL.N     1
# AMZN.O    1
# AEE.N     1
# AKS.N     1
# AEIS.O    1
# AIZ.N     1
# AFG.N     1
# ALV.N     1
# AER.N     1
# AAI.N     1
# AET.N     1
# AGN.N     1
# AFL.N     1
# AES.N     1
# AOC.N     1
# Name: assetCode, Length: 100, dtype: int64

# %%
from kaggle.competitions import twosigmanews
env = twosigmanews.make_env()
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-1b472a4a1aae> in <module>()
# ----> 1 from kaggle.competitions import twosigmanews
#       2 env = twosigmanews.make_env()
#
# ModuleNotFoundError: No module named 'kaggle.competitions'
